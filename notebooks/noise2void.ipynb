# %% [markdown]
# # Noise2Void
# Denoising with Noise2Void

# %%
from pathlib import Path
import torch
from careamics import CAREamist
from careamics.config import create_n2v_configuration
from sphero_vem.utils import TiffDataset

# Set lower matmul precision to use tensor cores
torch.set_float32_matmul_precision("high")

# %%
work_dir = Path("../data/models/n2v")
work_dir.mkdir(exist_ok=True, parents=True)

config = create_n2v_configuration(
    experiment_name="n2v_2D",
    data_type="tiff",
    axes="YX",
    patch_size=[64, 64],
    batch_size=8,
    num_epochs=20,
)

careamist = CAREamist(config, work_dir=work_dir)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
# train_data_path = Path("../data/raw/Au_01-vol_01")

# careamist.train(train_source=train_data_path, val_percentage=0.2)

# %%
train_data_path = Path("../data/raw/Au_01-vol_01")
train_data = TiffDataset(train_data_path)

# %%
# Out:
# torch.Size([10240, 5, 10240])
